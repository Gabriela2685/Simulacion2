# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriela2685/Simulacion2/blob/main/Muestra_import.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random as rnd
import matplotlib.pyplot as plt

# %%
def muestra(n):  # Definimos nuestra funsion muestra
  lista=[]    # Creamos una lista para almacenar los valores de x
  for i in range(n):
    y = rnd.random()  #Generamos valores aleatorios uniformes para y
    u = rnd.random()  # Generamos valores aleatorios uniformes para u
    if u <= ((3/2)*(1-y**2))/(12): # Aplicamos la razon de aceptación
      x = y  # Almacenamos el valor de x
      lista.append(x) # Almacenamos el valor de x en la lista
  return lista

# %%
H = muestra(10000)

# %%
plt.plot(H)
